# %%
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# Provide image size
IMAGE_SIZE = [224, 224]

# Give our training and testing path
training_data = r'/Users/aruni/VScode_Workspace/project/breast_xray/train'
testing_data = r'/Users/aruni/VScode_Workspace/project/breast_xray/test'

# Find how many classes are present in the train dataset
folders = glob(r'/Users/aruni/VScode_Workspace/project/breast_xray/train/*')

# ANN Model
input_shape = IMAGE_SIZE + [3]
model = tf.keras.Sequential([
    Flatten(input_shape=input_shape),
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    Dense(len(folders), activation='softmax')
])

# View the structure of the model
model.summary()

# Compiling our model
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# ImageDataGenerators
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# Set up the data generators
training_set = train_datagen.flow_from_directory(training_data,
                                                 target_size = IMAGE_SIZE,
                                                 batch_size = 10,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(testing_data,
                                            target_size = IMAGE_SIZE,
                                            batch_size = 10,
                                            class_mode = 'categorical')

# Fitting the model
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=5, # Change the number of epochs if needed
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)

# Save the model
model.save('ann_model.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 150528)            0
#
#  dense (Dense)               (None, 1024)              154141696
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 0)                 0
#
# =================================================================
# Total params: 154666496 (590.01 MB)
# Trainable params: 154666496 (590.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 50
#      47 test_datagen = ImageDataGenerator(rescale = 1./255)
#      49 # Set up the data generators
# ---> 50 training_set = train_datagen.flow_from_directory(training_data,
#      51                                                  target_size = IMAGE_SIZE,
#      52                                                  batch_size = 10,
#      53                                                  class_mode = 'categorical')
#      55 test_set = test_datagen.flow_from_directory(testing_data,
#      56                                             target_size = IMAGE_SIZE,
#      57                                             batch_size = 10,
#      58                                             class_mode = 'categorical')
#      60 # Fitting the model
#
# File /opt/homebrew/lib/python3.11/site-packages/keras/src/preprocessing/image.py:1649, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1562 def flow_from_directory(
#    1563     self,
#    1564     directory,
#    (...)
#    1578     keep_aspect_ratio=False,
#    1579 ):
#    1580     """Takes the path to a directory & generates batches of augmented data.
#    1581
#    1582     Args:
#    (...)
#    1647         and `y` is a numpy array of corresponding labels.
#    1648     """
# -> 1649     return DirectoryIterator(
#    1650         directory,
#    1651         self,
#    1652         target_size=target_size,
#    1653         color_mode=color_mode,
#    1654         keep_aspect_ratio=keep_aspect_ratio,
#    1655         classes=classes,
#    1656         class_mode=class_mode,
#    1657         data_format=self.data_format,
#    1658         batch_size=batch_size,
#    1659         shuffle=shuffle,
#    1660         seed=seed,
#    1661         save_to_dir=save_to_dir,
#    1662         save_prefix=save_prefix,
#    1663         save_format=save_format,
#    1664         follow_links=follow_links,
#    1665         subset=subset,
#    1666         interpolation=interpolation,
#    1667         dtype=self.dtype,
#    1668     )
#
# File /opt/homebrew/lib/python3.11/site-packages/keras/src/preprocessing/image.py:563, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     561 if not classes:
#     562     classes = []
# --> 563     for subdir in sorted(os.listdir(directory)):
#     564         if os.path.isdir(os.path.join(directory, subdir)):
#     565             classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../breast_xray/train'
